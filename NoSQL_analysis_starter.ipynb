# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
uk_food = mongo['uk_food']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %%
# review the collections in our database
uk_food.list_collection_names()
# Out:
# ['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
# When looking at how to find the hygiene score, I see that they are within scores
# and tabed hence why we used the period and we are also seeting it to find a vlaue of 20
hygiene =  {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(hygiene)
print(f"Number of establishments with a hygiene score of 20: {count_documents} ")
      
# Display the first document in the results using pprint
pprint(establishments.find_one(hygiene))
# Out:
# Number of establishments with a hygiene score of 20: 41
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64d3fd8549de917cce94df90'),
#  'geocode': {'latitude': '50.769705', 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_score = pd.DataFrame(establishments.find(hygiene))

# Display the number of rows in the DataFrame
print(f"There are {len(hygiene_score)} rows in this data frame.")

# Display the first 10 rows of the DataFrame
hygiene_score.head(10)
# Out:
# There are 41 rows in this data frame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64d3fd8549de917cce94df90   110681                  0
# 1  64d3fd8549de917cce94e306   612039                  0
# 2  64d3fd8549de917cce94e610   730933                  0
# 3  64d3fd8549de917cce94e7ff   172735                  0
# 4  64d3fd8549de917cce94e810   172953                  0
# 5  64d3fd8549de917cce94f1b4   512854                  0
# 6  64d3fd8549de917cce94f3d1  1537089                  0
# 7  64d3fd8549de917cce9508f5   155648                  0
# 8  64d3fd8549de917cce950d3c  1012883                  0
# 9  64d3fd8549de917cce95154a   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
# A lot of these steps are similar to what we did above
Rate = {"LocalAuthorityName": "London", "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count_Rate = establishments.count_documents(Rate)
print(f"Number of establishments with a rating value of 4 and in London: {count_Rate} ")

# Display the first document in the results using pprint
pprint(establishments.find_one(Rate))
# Out:
# Number of establishments with a rating value of 4 and in London: 0
# None

# %%
# Find the establishments with Folkestone and Hythe as the Local Authority and has a RatingValue greater than or equal to 4.
# Since there were zero for London I still wanted to make a data set that worked so instead used Folkestone and Hythe
Rated = {"LocalAuthorityName": "Folkestone and Hythe", "RatingValue": {"$gte": 4}}

# Use count_documents to display the number of documents in the result
count_Rated = establishments.count_documents(Rated)
print(f"Number of establishments with a rating value of 4 and in Folkestone and Hythe: {count_Rated} ")

# Display the first document in the results using pprint
pprint(establishments.find_one(Rated))
# Out:
# Number of establishments with a rating value of 4 and in Folkestone and Hythe: 839
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64d3fd8449de917cce94c450'),
#  'geocode': {'latitude': '51.083812', 'longitude': 1.195625},
# ...

# %%
# Convert the result to a Pandas DataFrame
rating_score = pd.DataFrame(establishments.find(Rated))

# Display the number of rows in the DataFrame
print(f"There are {len(rating_score)} rows in this data frame.")

# Display the first 10 rows of the DataFrame
rating_score.head(10)
# Out:
# There are 839 rows in this data frame.
#                         _id   FHRSID  ChangesByServerID  \
# 0  64d3fd8449de917cce94c450  1043695                  0
# 1  64d3fd8449de917cce94c452   647177                  0
# 2  64d3fd8449de917cce94c456   289352                  0
# 3  64d3fd8449de917cce94c458   289353                  0
# 4  64d3fd8449de917cce94c459  1043701                  0
# 5  64d3fd8449de917cce94c45a   344689                  0
# 6  64d3fd8449de917cce94c45b   987206                  0
# 7  64d3fd8449de917cce94c45c   894592                  0
# 8  64d3fd8449de917cce94c45f  1423242                  0
# 9  64d3fd8449de917cce94c460  1068284                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000073616                         The Pavilion
# 1             PI/000041489                  Wear Bay Bowls Club
# 2             PI/000002460                             The Ship
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Reused this line of code from the previous work sheet in order to get quardiantes 
pprint(establishments.find_one({'BusinessName':'Penang Flavours'}))
# Out:
# {'AddressLine1': '123 Greenwich Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Greenwich',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'FHRSID': 1290215,
#  'LocalAuthorityBusinessID': 'PI/000083029',
#  'LocalAuthorityCode': '123',
#  'LocalAuthorityEmailAddress': 'healthdepartment@greenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich Borough',
#  'LocalAuthorityWebSite': 'http://www.greenwich.gov.uk/',
#  'Phone': '123-456-7890',
#  'PostCode': 'SE10 9XX',
#  'RatingDate': '2023-08-09T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 8,
#  '_id': '64d3fd8449de917cce94c43e',
#  'geocode': {'Distance': 0, 'RightToReply': '', 'longitude': None},
#  'scores': {'SchemeType': 'FHRS'}}

# %%
#Since it seems as if I didn;t make quardinates for it ill get one from a random restaurant
pprint(establishments.find_one({'BusinessName':'Pick Up Pintxos'}))
# Out:
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Pick Up Pintxos',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1043701,
#  'LocalAuthorityBusinessID': 'PI/000076360',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-04-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64d3fd8449de917cce94c459'),
#  'geocode': {'latitude': '51.0783519967076', 'longitude': 1.18590330311705},
# ...

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
degree_search = 0.01

# These are quardinates from the restaurnat above as i didnt set a lat and long for Peneng flavors
latitude = 51.0783519967076
longitude = 1.18590330311705

query = {"Latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
         "Longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
         "RatingValue": "5"
}
sort = [("scores.Hygiene", 1)]

# We are told to find the top 5 so im limiting to 5
limit = 5

# Print the results
results = list(establishments.find(Rated).sort(sort).limit(limit))
pprint(results)
# Out:
# [{'AddressLine1': '24-26 Harbour Street',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Harbour Inn',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.981553562698,
#   'FHRSID': 1023912,
#   'LocalAuthorityBusinessID': 'PI/000076188',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT20 1QN',
#   'RatingDate': '2022-05-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('64d3fd8449de917cce94c490'),
#   'geocode': {'latitude': '51.079613', 'longitude': 1.185368},
# ...

# %%
# Convert result to Pandas DataFrame
top_5 = pd.DataFrame(results)
top_5.head(5)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64d3fd8449de917cce94c490  1023912                  0
# 1  64d3fd8449de917cce94c4b5  1380216                  0
# 2  64d3fd8449de917cce94c492   511409                  0
# 3  64d3fd8449de917cce94c46e  1058636                  0
# 4  64d3fd8449de917cce94c45f  1423242                  0
#
#   LocalAuthorityBusinessID  BusinessName             BusinessType  \
# 0             PI/000076188   Harbour Inn        Pub/bar/nightclub
# 1             PI/000078113    Lucky Chip  Restaurant/Cafe/Canteen
# 2             PI/000039931  The Lifeboat        Pub/bar/nightclub
# 3             PI/000076450        Babaji   Takeaway/sandwich shop
# 4             PI/000078141   Little Rock  Other catering premises
#
#    BusinessTypeID                    AddressLine1           AddressLine2  \
# 0            7843            24-26 Harbour Street             Folkestone
# 1               1  Ground Floor Business Premises        2 Church Street
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

# Execute the aggregation pipeline
result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"Number of documents in the result: {len(result)}")

# Print the first 10 results
print("First 10 results:")
for item in result[:10]:
    print(item)
# Out:
# Number of documents in the result: 55
# First 10 results:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
local = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print(f"There are {len(result)} rows in this data frame.")

# Display the first 10 rows of the DataFrame
local.head(10)
# Out:
# There are 55 rows in this data frame.
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
